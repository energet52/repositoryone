# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
sns.set_style('darkgrid')

# %%
data = pd.read_excel('/Users/alexandernovoselov/Google Drive/Dropbox (Personal)/Natik/Studium/Disertace/2017analysis_python.xlsx',sheet_name='Sheet1', index_col='DMU')

# %%
data.head()
# Out:
#          Social  Financial
# DMU
# A104408   11.17      89.15
# A104165   27.78      89.66
# A100702   64.06       6.63
# A145992    7.18      42.76
# A114953   43.22      83.50

# %%
sns.jointplot(x='Social',y='Financial',data=data,kind='hex')
sns.jointplot(x='Social',y='Financial',data=data,kind='kde')
sns.jointplot(x='Social',y='Financial',data=data,kind='scatter')

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x='Social',y='Financial',data=data)
